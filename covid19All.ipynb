# %%
# importing the required libraries
import pandas as pd
import numpy as np

# Visualisation libraries
import plotly.express as px
import plotly.graph_objects as go

# %%
df_data= pd.read_json('https://covid.ourworldindata.org/data/owid-covid-data.json')
df = df_data.copy()
# df.sort_values(by=['salary'], ascending=False, inplace=True) # sorting
# df.style.background_gradient(cmap='Greens')
# df['sl'] = list(range(len(df.index)))
df.head(10)
# Out:
#                                AFG         ALB  ...         ZMB          ZWE
# continent                     Asia      Europe  ...      Africa       Africa
# location               Afghanistan     Albania  ...      Zambia     Zimbabwe
# population             3.89283e+07  2.8778e+06  ...  1.8384e+07  1.48629e+07
# population_density          54.422     104.871  ...      22.995       42.729
# median_age                    18.6          38  ...        17.7         19.6
# aged_65_older                2.581      13.188  ...        2.48        2.822
# aged_70_older                1.337       8.643  ...       1.542        1.882
# gdp_per_capita             1803.99     11803.4  ...     3689.25      1899.78
# cardiovasc_death_rate      597.029     304.195  ...     234.499      307.846
# diabetes_prevalence           9.59       10.08  ...        3.94         1.82
#
# [10 rows x 191 columns]

# %%
df['BGD']
# Out:
# continent                                                                  Asia
# location                                                             Bangladesh
# population                                                          1.64689e+08
# population_density                                                      1265.04
# median_age                                                                 27.5
# aged_65_older                                                             5.098
# aged_70_older                                                             3.262
# gdp_per_capita                                                          3523.98
# cardiovasc_death_rate                                                   298.003
# diabetes_prevalence                                                        8.38
# handwashing_facilities                                                   34.808
# hospital_beds_per_thousand                                                  0.8
# ...

# %%
df_bd = df['BGD'].data
df_bd[2]
# Out:
# {'date': '2020-03-05',
#  'stringency_index': 13.89,
#  'tests_units': 'tests performed'}

# %%
# df_bd = np.array(df_bd)
# dataset = pd.DataFrame(df_bd)
# len(dataset)
# date = []
# stringency = []
# for x in df_bd:
#   date.append(x['date'])
#   stringency.append(x['stringency_index'])
#   # print(x['stringency_index'])
#   # if new_deaths in df_bd:
#   #   new_deaths.append(x['new_deaths'])
# # date
# date =np.asarray(date)
# stringency =np.asarray(stringency)
# stringency
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-127-1319eb83dd77> in <module>()
#       6 for x in df_bd:
#       7   date.append(x['date'])
# ----> 8   stringency.append(x['stringency_index'])
#       9   # print(x['stringency_index'])
#      10   # if new_deaths in df_bd:
#
# KeyError: 'stringency_index'

# %%
df_bd[2]
# Out:
# {'date': '2020-03-05',
#  'stringency_index': 13.89,
#  'tests_units': 'tests performed'}
