# %%
# !rm daily-sales-collection-2020-12-21.xlsx
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bf71f3ed-5158-4d63-ada6-3bc992a0e16f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bf71f3ed-5158-4d63-ada6-3bc992a0e16f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving daily-sales-collection-2020-12-21.xlsx to daily-sales-collection-2020-12-21.xlsx

# %%
# importing the required libraries
import pandas as pd
import numpy as np

# Visualisation libraries
import plotly.express as px
import plotly.graph_objects as go

# %%
df_data= pd.read_excel('daily-sales-collection-2020-12-21.xlsx')
df = df_data.copy()
df.sort_values(by=['Center Name'], inplace=True) # sorting by sales center
df.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
# #T_34838582_459f_11eb_aef7_0242ac1c0002row0_col0,#T_34838582_459f_11eb_aef7_0242ac1c0002row57_col4{
#             background-color:  #fcb99f;
#             color:  #000000;
#         }#T_34838582_459f_11eb_aef7_0242ac1c0002row0_col3,#T_34838582_459f_11eb_aef7_0242ac1c0002row59_col8{
#             background-color:  #fdd4c2;
#             color:  #000000;
#         }#T_34838582_459f_11eb_aef7_0242ac1c0002row0_col4,#T_34838582_459f_11eb_aef7_0242ac1c0002row34_col4,#T_34838582_459f_11eb_aef7_0242ac1c0002row55_col8{
#             background-color:  #fed9c9;
#             color:  #000000;
#         }#T_34838582_459f_11eb_aef7_0242ac1c0002row0_col5,#T_34838582_459f_11eb_aef7_0242ac1c0002row0_col7,#T_34838582_459f_11eb_aef7_0242ac1c0002row9_col0,#T_34838582_459f_11eb_aef7_0242ac1c0002row34_col3,#T_34838582_459f_11eb_aef7_0242ac1c0002row35_col10{
#             background-color:  #fdd3c1;
#             color:  #000000;
# ...

# %%
df_data= pd.read_excel('sales-center.xlsx')
df2 = df_data.copy()
df2.style.background_gradient(cmap='Greens')
# Out:
# <style  type="text/css" >
# #T_3c87b47e_459f_11eb_aef7_0242ac1c0002row0_col0{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }#T_3c87b47e_459f_11eb_aef7_0242ac1c0002row1_col0{
#             background-color:  #f5fbf2;
#             color:  #000000;
#         }#T_3c87b47e_459f_11eb_aef7_0242ac1c0002row2_col0{
#             background-color:  #f2faf0;
#             color:  #000000;
#         }#T_3c87b47e_459f_11eb_aef7_0242ac1c0002row3_col0{
#             background-color:  #f0f9ec;
#             color:  #000000;
#         }#T_3c87b47e_459f_11eb_aef7_0242ac1c0002row4_col0{
#             background-color:  #edf8ea;
#             color:  #000000;
#         }#T_3c87b47e_459f_11eb_aef7_0242ac1c0002row5_col0{
#             background-color:  #ebf7e7;
#             color:  #000000;
#         }#T_3c87b47e_459f_11eb_aef7_0242ac1c0002row6_col0{
#             background-color:  #e8f6e4;
#             color:  #000000;
# ...

# %%
# Merge 2 fiels and make unique data
df = pd.concat([df, df2]).drop_duplicates('Center Name').reset_index(drop=True).fillna(0)
df1 = pd.concat([df1, df2]).drop_duplicates('Center Name').reset_index(drop=True).fillna(0)

# Replace manager fileds
df['Manager'] = df['Manager'].replace([0], '')
df1['Manager'] = df1['Manager'].replace([0], '')

# Sorting by Sales Center
df.sort_values(by=['Center Name'], inplace=True)
df1.sort_values(by=['Center Name'], inplace=True)

# Getting data df and df1

# %%
# Sales Comparision
df_sales = format(df['Gross Sales'].sum(), ',.2f')
df_sales1 = format(df1['Gross Sales'].sum(), ',.2f')
title_text = "Sales Comparision 2020-12-21("+ str(df_sales)+"tk. ) & 2020-12-22("+ str(df_sales1)+"tk.)"

fig = go.Figure(data=[
    go.Bar(x=df["Center Name"], y=df["Gross Sales"], name='2020-12-21'),
    go.Bar(x=df1["Center Name"], y=df1["Gross Sales"], name='2020-12-22')
])
fig.update_traces(hovertemplate='%{x}<br>Tk. %{y:.0f}')
fig.update_layout(title_text=title_text, xaxis_tickfont_size=12, yaxis=dict(title='Sales Amount'), plot_bgcolor='rgb(230, 230, 230)')
fig.update_layout(barmode='group')
fig.show()

fig = go.Figure()
fig.add_trace(go.Scatter(x=df['Center Name'], y = df['Gross Sales'], mode='lines+markers', name='2020-12-21',line=dict(color='blue', width=2)))
fig.add_trace(go.Scatter(x=df1['Center Name'], y = df1['Gross Sales'], mode='lines+markers', name='2020-12-22',line=dict(color='Green', width=2)))
fig.update_traces(hovertemplate='%{x}<br>Tk. %{y:.0f}')
fig.update_layout(title='Sales Comparision', xaxis_tickfont_size=12, yaxis=dict(title='Sales Amount'), plot_bgcolor='rgb(230, 230, 230)', height=600)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="875bee30-8d16-4257-8675-5c57fe5fab53" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("875bee30-8d16-4257-8675-5c57fe5fab53")) {
#                     Plotly.newPlot(
#                         '875bee30-8d16-4257-8675-5c57fe5fab53',
# ...

# %%
# Collection Comparision
df_collection = format(df['Collection'].sum(), ',.2f')
df_collection1 = format(df1['Collection'].sum(), ',.2f')
title_text = "Collection Comparision 2020-12-21("+ str(df_collection)+"tk. ) & 2020-12-22("+ str(df_collection1)+"tk.)"

fig = go.Figure(data=[
    go.Bar(x=df["Center Name"], y=df["Collection"], name='2020-12-21'),
    go.Bar(x=df1["Center Name"], y=df1["Collection"], name='2020-12-22')
])
fig.update_traces(hovertemplate='%{x}<br>Tk. %{y:.0f}')
fig.update_layout(title_text=title_text, xaxis_tickfont_size=12, yaxis=dict(title='Collection Amount'), plot_bgcolor='rgb(230, 230, 230)')
fig.update_layout(barmode='group')
fig.show()

fig = go.Figure()
fig.add_trace(go.Scatter(x=df['Center Name'], y = df['Collection'], mode='lines+markers', name='2020-12-21',line=dict(color='blue', width=2)))
fig.add_trace(go.Scatter(x=df1['Center Name'], y = df1['Collection'], mode='lines+markers', name='2020-12-22',line=dict(color='red', width=2)))
fig.update_traces(hovertemplate='%{x}<br>Tk. %{y:.0f}')
fig.update_layout(title=title_text, xaxis_tickfont_size=12, yaxis=dict(title='Collection Amount'), plot_bgcolor='rgb(230, 230, 230)', height=600)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="83663d26-6299-4448-aeda-658e89342491" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("83663d26-6299-4448-aeda-658e89342491")) {
#                     Plotly.newPlot(
#                         '83663d26-6299-4448-aeda-658e89342491',
# ...
