# %%
import numpy as np

# %%
import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20200101', periods=10)
dates
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(10, 7), index=dates, columns=list('ABCDEFG'))
df
# Out:
#                    A         B         C  ...         E         F         G
# 2020-01-01  0.231649 -0.278813 -0.055106  ... -0.349899 -0.250844  1.271888
# 2020-01-02  0.203658  0.112563 -1.884227  ...  1.008711  0.074796 -0.037580
# 2020-01-03 -0.225426  0.885799  0.310275  ...  0.083951 -0.683854 -0.202764
# 2020-01-04  0.386710 -1.263492 -0.173906  ...  0.160408 -0.780399  0.207157
# 2020-01-05 -1.744668  0.051990  0.050989  ...  0.683550 -1.378425  0.357663
# 2020-01-06 -0.116097 -0.006387  0.386994  ...  1.061863  0.014839 -0.981722
# 2020-01-07  1.410043 -0.145397 -1.259857  ...  1.390848 -1.593561 -0.788412
# 2020-01-08 -1.268422 -1.362272 -0.688547  ...  0.097552  0.416440  1.086886
# 2020-01-09  1.536070 -0.749957 -0.140548  ... -0.857338  0.757153  0.159245
# 2020-01-10 -0.239229  0.672879  0.105209  ...  1.970902 -0.566356 -1.305806
#
# [10 rows x 7 columns]

# %%
df2 = pd.DataFrame({
  'A': 1.,
  'B': pd.Timestamp('20200102'),
  'C': pd.Series(1, index=list(range(4)), dtype='float32'),
  'D': np.array([3] * 4, dtype='int32'),
  'E': pd.Categorical(["test", "train", "test", "train"]),
  'F': 'Sohel'
})
df2
# Out:
#      A          B    C  D      E      F
# 0  1.0 2020-01-02  1.0  3   test  Sohel
# 1  1.0 2020-01-02  1.0  3  train  Sohel
# 2  1.0 2020-01-02  1.0  3   test  Sohel
# 3  1.0 2020-01-02  1.0  3  train  Sohel

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C  ...         E         F         G
# 2020-01-01  0.231649 -0.278813 -0.055106  ... -0.349899 -0.250844  1.271888
# 2020-01-02  0.203658  0.112563 -1.884227  ...  1.008711  0.074796 -0.037580
# 2020-01-03 -0.225426  0.885799  0.310275  ...  0.083951 -0.683854 -0.202764
# 2020-01-04  0.386710 -1.263492 -0.173906  ...  0.160408 -0.780399  0.207157
# 2020-01-05 -1.744668  0.051990  0.050989  ...  0.683550 -1.378425  0.357663
#
# [5 rows x 7 columns]

# %%
df.tail(3)
# Out:
#                    A         B         C  ...         E         F         G
# 2020-01-08 -1.268422 -1.362272 -0.688547  ...  0.097552  0.416440  1.086886
# 2020-01-09  1.536070 -0.749957 -0.140548  ... -0.857338  0.757153  0.159245
# 2020-01-10 -0.239229  0.672879  0.105209  ...  1.970902 -0.566356 -1.305806
#
# [3 rows x 7 columns]

# %%
df.index
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[ 0.23164858, -0.27881291, -0.05510584, -1.71266966, -0.34989917,
#         -0.25084371,  1.27188807],
#        [ 0.20365823,  0.11256306, -1.88422691,  1.46807064,  1.00871062,
#          0.07479582, -0.03757978],
#        [-0.22542559,  0.88579948,  0.31027519,  0.5210312 ,  0.08395059,
#         -0.68385443, -0.20276393],
#        [ 0.38670958, -1.26349176, -0.17390628, -0.01410387,  0.16040787,
#         -0.78039889,  0.20715693],
#        [-1.7446684 ,  0.05198986,  0.05098881,  0.71374935,  0.68354969,
#         -1.37842452,  0.35766268],
#        [-0.11609703, -0.00638657,  0.38699356, -0.88767326,  1.06186259,
#          0.01483922, -0.98172206],
#        [ 1.41004349, -0.14539717, -1.25985654, -0.59629251,  1.39084817,
#         -1.59356122, -0.7884121 ],
#        [-1.26842247, -1.36227238, -0.68854739, -0.36278577,  0.09755152,
#          0.41644007,  1.08688635],
#        [ 1.53607024, -0.74995651, -0.14054839, -0.23458082, -0.85733767,
#          0.75715295,  0.15924467],
#        [-0.23922934,  0.67287859,  0.10520927,  0.58342755,  1.97090187,
#         -0.56635633, -1.30580551]])

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2020-01-02 00:00:00'), 1.0, 3, 'test', 'Sohel'],
#        [1.0, Timestamp('2020-01-02 00:00:00'), 1.0, 3, 'train', 'Sohel'],
#        [1.0, Timestamp('2020-01-02 00:00:00'), 1.0, 3, 'test', 'Sohel'],
#        [1.0, Timestamp('2020-01-02 00:00:00'), 1.0, 3, 'train', 'Sohel']],
#       dtype=object)

# %%
df.describe()
# Out:
#                A          B          C  ...          E          F          G
# count  10.000000  10.000000  10.000000  ...  10.000000  10.000000  10.000000
# mean    0.017429  -0.208309  -0.334872  ...   0.525055  -0.399021  -0.023344
# std     1.020004   0.740301   0.730524  ...   0.854669   0.749829   0.838172
# min    -1.744668  -1.362272  -1.884227  ...  -0.857338  -1.593561  -1.305806
# 25%    -0.235778  -0.632171  -0.559887  ...   0.087351  -0.756263  -0.642000
# 50%     0.043781  -0.075892  -0.097827  ...   0.421979  -0.408600   0.060832
# 75%     0.347944   0.097420   0.091654  ...   1.048575   0.059807   0.320036
# max     1.536070   0.885799   0.386994  ...   1.970902   0.757153   1.271888
#
# [8 rows x 7 columns]

# %%
df.T
# Out:
#    2020-01-01  2020-01-02  2020-01-03  ...  2020-01-08  2020-01-09  2020-01-10
# A    0.231649    0.203658   -0.225426  ...   -1.268422    1.536070   -0.239229
# B   -0.278813    0.112563    0.885799  ...   -1.362272   -0.749957    0.672879
# C   -0.055106   -1.884227    0.310275  ...   -0.688547   -0.140548    0.105209
# D   -1.712670    1.468071    0.521031  ...   -0.362786   -0.234581    0.583428
# E   -0.349899    1.008711    0.083951  ...    0.097552   -0.857338    1.970902
# F   -0.250844    0.074796   -0.683854  ...    0.416440    0.757153   -0.566356
# G    1.271888   -0.037580   -0.202764  ...    1.086886    0.159245   -1.305806
#
# [7 rows x 10 columns]

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    G         F         E  ...         C         B         A
# 2020-01-01  1.271888 -0.250844 -0.349899  ... -0.055106 -0.278813  0.231649
# 2020-01-02 -0.037580  0.074796  1.008711  ... -1.884227  0.112563  0.203658
# 2020-01-03 -0.202764 -0.683854  0.083951  ...  0.310275  0.885799 -0.225426
# 2020-01-04  0.207157 -0.780399  0.160408  ... -0.173906 -1.263492  0.386710
# 2020-01-05  0.357663 -1.378425  0.683550  ...  0.050989  0.051990 -1.744668
# 2020-01-06 -0.981722  0.014839  1.061863  ...  0.386994 -0.006387 -0.116097
# 2020-01-07 -0.788412 -1.593561  1.390848  ... -1.259857 -0.145397  1.410043
# 2020-01-08  1.086886  0.416440  0.097552  ... -0.688547 -1.362272 -1.268422
# 2020-01-09  0.159245  0.757153 -0.857338  ... -0.140548 -0.749957  1.536070
# 2020-01-10 -1.305806 -0.566356  1.970902  ...  0.105209  0.672879 -0.239229
#
# [10 rows x 7 columns]

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C  ...         E         F         G
# 2020-01-08 -1.268422 -1.362272 -0.688547  ...  0.097552  0.416440  1.086886
# 2020-01-04  0.386710 -1.263492 -0.173906  ...  0.160408 -0.780399  0.207157
# 2020-01-09  1.536070 -0.749957 -0.140548  ... -0.857338  0.757153  0.159245
# 2020-01-01  0.231649 -0.278813 -0.055106  ... -0.349899 -0.250844  1.271888
# 2020-01-07  1.410043 -0.145397 -1.259857  ...  1.390848 -1.593561 -0.788412
# 2020-01-06 -0.116097 -0.006387  0.386994  ...  1.061863  0.014839 -0.981722
# 2020-01-05 -1.744668  0.051990  0.050989  ...  0.683550 -1.378425  0.357663
# 2020-01-02  0.203658  0.112563 -1.884227  ...  1.008711  0.074796 -0.037580
# 2020-01-10 -0.239229  0.672879  0.105209  ...  1.970902 -0.566356 -1.305806
# 2020-01-03 -0.225426  0.885799  0.310275  ...  0.083951 -0.683854 -0.202764
#
# [10 rows x 7 columns]
