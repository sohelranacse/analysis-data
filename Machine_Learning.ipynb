# %%
# Mean, Median, and Mode
# Mean
import numpy

speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = numpy.mean(speed)

print(x)
# Out:
# 89.76923076923077

# %%
# Median
speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = numpy.median(speed)

print(x)
# Out:
# 87.0

# %%
speed = [99,86,87,88,86,103,87,94,78,77,85,86]

x = numpy.median(speed)

print(x)
# Out:
# 86.5

# %%
# Mode
from scipy import stats

speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = stats.mode(speed)

print(x)
# Out:
# ModeResult(mode=array([86]), count=array([3]))

# %%
# Standard Deviation
speed = [86,87,88,86,87,85,86]

x = numpy.std(speed)

print(x)
# Out:
# 0.9035079029052513

# %%
speed = [32,111,138,28,59,77,97]

x = numpy.std(speed)

print(x)
# Out:
# 37.84501153334721

# %%
# Variance
speed = [32,111,138,28,59,77,97]

x = numpy.var(speed)

print(x)
# Out:
# 1432.2448979591834

# %%
speed = [32,111,138,28,59,77,97]

x = numpy.std(speed)

print(x)
# Out:
# 37.84501153334721

# %%
# Percentiles
ages = [5,31,43,48,50,41,7,11,15,39,80,82,32,2,8,6,25,36,27,61,31]

x = numpy.percentile(ages, 75)

print(x)
# Out:
# 43.0

# %%
ages = [5,31,43,48,50,41,7,11,15,39,80,82,32,2,8,6,25,36,27,61,31]

x = numpy.percentile(ages, 90)

print(x)
# Out:
# 61.0

# %%
# Data Distribution
x = numpy.random.uniform(0.0, 5.0, 250)

print(x)
# Out:
# [4.31052415e+00 4.08802001e+00 3.83622818e+00 2.15322176e-02
#  3.25876713e+00 2.41601721e+00 1.83377969e+00 2.36702502e+00
#  4.10199676e+00 1.37550625e+00 2.48921934e+00 1.57153052e-01
#  2.42111916e+00 4.06727078e+00 2.20327776e-02 1.53762723e+00
#  3.61286407e+00 2.87551272e+00 2.82177944e-02 2.75745657e+00
#  4.51606619e+00 2.85442622e+00 2.18356634e+00 4.15841210e-01
#  4.31122819e+00 3.81440000e+00 2.07291138e+00 2.48265958e+00
#  2.90533202e+00 4.97498361e+00 4.46477123e+00 4.54835297e+00
#  7.99028647e-01 4.85769969e+00 5.15775354e-01 3.51481557e+00
#  1.49250868e+00 2.56355019e+00 3.86487792e+00 1.16053341e+00
#  4.55171293e+00 3.60176071e+00 8.05922260e-02 3.92514734e+00
#  1.76311882e+00 2.52711859e+00 1.60402667e+00 2.35300304e+00
#  4.37983494e+00 4.45574641e+00 6.91137219e-01 2.52791304e+00
#  3.65456003e+00 2.95684330e+00 4.90996910e+00 3.14193875e+00
#  3.91636965e+00 4.28916301e+00 3.92545732e+00 3.87730451e+00
#  4.92678627e+00 1.11196765e+00 2.10914181e+00 4.65013457e+00
#  1.40804763e+00 4.66530819e+00 1.73853124e+00 2.77802611e+00
#  4.76499997e+00 8.64624691e-01 3.69719361e+00 4.25326052e+00
#  2.14554879e+00 4.22408567e+00 2.75337364e+00 2.70660619e+00
#  4.61851171e+00 1.39332798e+00 2.27155944e+00 3.64341528e-01
#  6.56501275e-01 3.88428302e+00 3.56829421e+00 3.72129337e+00
#  7.10236728e-01 4.40439943e+00 4.11183589e+00 2.92303070e-01
#  3.00849200e+00 6.80638568e-01 3.84043252e+00 3.33388183e-02
#  9.80211869e-01 3.19328635e+00 2.83873280e-01 5.65875552e-01
#  1.19391779e+00 3.86761480e+00 2.01746028e-01 2.10225719e+00
#  4.21938196e+00 4.65468146e+00 1.10734381e+00 1.44496103e+00
#  3.96650755e+00 1.32836006e-01 1.03961038e+00 4.73249897e+00
#  2.70570082e-01 1.52041421e+00 1.37539796e+00 4.76935348e+00
#  4.08352122e+00 4.32739613e-01 3.26316853e+00 5.54786754e-01
#  4.56156964e+00 9.23455274e-01 2.44791325e+00 3.58465886e+00
#  4.75307524e+00 2.36933540e+00 4.36106250e+00 2.04142738e+00
#  2.47427464e+00 3.10621119e+00 3.75377220e+00 1.14967679e+00
#  3.44672607e-01 1.15416233e+00 9.39069466e-01 2.58862662e-03
#  2.94233504e+00 2.71546165e+00 3.96579746e+00 4.38178769e+00
#  8.70563522e-01 4.15679702e+00 4.81523440e+00 2.02814553e+00
#  4.73291637e+00 1.12674247e+00 6.22461545e-01 2.40940578e+00
#  2.59827472e+00 1.48604168e+00 2.49197255e+00 4.47745264e+00
#  4.96105626e+00 3.74273668e+00 9.22364735e-01 2.05058816e+00
#  1.10430242e+00 4.14394707e+00 2.91520079e+00 4.19604243e+00
#  1.10381996e+00 1.12857334e+00 2.31002949e+00 2.97412978e+00
#  6.97055152e-01 7.41424311e-01 4.10319036e+00 1.58371990e+00
#  3.87848168e+00 3.02204106e+00 4.39411286e+00 2.32208939e+00
#  1.12314213e+00 3.62126527e+00 2.17498761e+00 8.43027370e-01
#  4.61278788e+00 3.23401799e+00 3.53374032e+00 4.32392282e+00
#  3.73435100e+00 6.66617205e-01 1.44334392e+00 3.77504626e+00
#  3.65003691e+00 4.06057035e+00 2.74079897e+00 2.81773548e+00
#  3.49488100e+00 4.79295675e-01 1.86325973e+00 1.22093473e+00
#  3.74754635e-01 1.96327252e+00 1.69470957e+00 4.34526300e+00
#  2.71543234e+00 3.48729113e+00 1.73477774e+00 3.74473528e+00
#  4.74512320e+00 2.05645345e-01 6.30539708e-01 1.90400829e+00
#  3.43016955e+00 4.96216532e+00 4.46829106e+00 3.61784128e+00
#  5.20144980e-02 2.75345132e+00 1.95874653e-01 2.35052036e+00
#  4.76688828e-02 5.44395717e-01 9.54227297e-01 1.60428326e+00
#  3.21751127e+00 1.80215368e+00 2.44985236e+00 2.15580441e+00
#  3.55534438e+00 2.15295091e-01 4.55317999e+00 3.12882910e+00
#  2.85663456e+00 4.91248260e-01 3.67514127e+00 7.57371797e-01
#  2.37849623e+00 3.36532148e+00 3.81886956e+00 3.45928172e+00
#  1.20722649e-01 3.40048043e+00 2.92395070e+00 1.83560304e+00
#  8.62159918e-01 5.16600366e-01 1.73622985e+00 3.67790003e-01
#  4.44858565e+00 4.14483504e-01 2.57325499e+00 1.70678273e+00
#  3.13200716e+00 1.64574848e+00 3.22454869e+00 2.69223279e+00
#  3.43423414e+00 3.04993775e+00 1.48572911e+00 3.20371582e-01
#  4.18130783e+00 4.26539002e+00]

# %%
# Histogram
import matplotlib.pyplot as plt

x = numpy.random.uniform(0.0, 5.0, 250)

plt.hist(x, 5)
plt.show()

# %%
# Big Data Distributions
x = numpy.random.uniform(0.0, 5.0, 100000)

plt.hist(x, 100)
plt.show()

# %%
# Normal Data Distribution
x = numpy.random.normal(5.0, 1.0, 100000)

plt.hist(x, 100)
plt.show()

# %%
# Scatter Plot
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %%
# Random Data Distributions
x = numpy.random.normal(5.0, 1.0, 1000)
y = numpy.random.normal(10.0, 2.0, 1000)

plt.scatter(x, y)
plt.show()

# %%
# Linear Regression
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

print(r)
# Out:
# -0.758591524376155

# %%
# Predict Future Values
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

speed = myfunc(10)

print(speed)
# Out:
# 85.59308314937454

# %%
x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

slope, intercept, r, p, std_err = stats.linregress(x, y)

print(r)
# Out:
# 0.01331814154297491

# %%
# Polynomial Regression
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

plt.scatter(x, y)
plt.show()

# %%
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

plt.scatter(x, y)
plt.show()

# %%
import numpy
from sklearn.metrics import r2_score

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

print(r2_score(y, mymodel(x)))
# Out:
# 0.9432150416451025

# %%
# Predict Future Values
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

speed = mymodel(17)
print(speed)
# Out:
# 88.87331269697991

# %%
# Bad Fit

x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

myline = numpy.linspace(2, 95, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %%
x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

print(r2_score(y, mymodel(x)))
# Out:
# 0.009952707566680652

# %%
# Multiple Regression
import pandas
