# %%
import warnings
warnings.filterwarnings('ignore')
# check prophet version
import fbprophet
# print version number
print('Prophet %s' % fbprophet.__version__)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
# Out:
# Prophet 0.7.1

# %%
df = pd.read_excel("https://github.com/shabbirg89/Time-series-Analysis-on-Covid-19-New-Cases-Deaths-using-Fbprophet-in-R-Python/raw/master/25_onwards.xlsx",header=0)
df
# Out:
#           Date  Total Cases  New Cases  ...   Deaths  Unnamed: 6  Unnamed: 7
# 0   2020-03-25        606.0        6.0  ...     10.0         NaN         NaN
# 1   2020-03-26        606.0        0.0  ...     10.0         NaN         NaN
# 2   2020-03-27        694.0      100.0  ...     16.0         NaN         NaN
# 3   2020-03-28        798.0       81.0  ...     19.0         NaN         NaN
# 4   2020-03-29        931.0      105.0  ...     25.0         NaN         NaN
# ..         ...          ...        ...  ...      ...         ...         ...
# 165 2020-09-06    4202575.0    69624.0  ...  71103.0         NaN         NaN
# 166 2020-09-07    4277597.0    74123.0  ...  72232.0         NaN         NaN
# 167 2020-09-08    4367449.0    74607.0  ...  73339.0         NaN         NaN
# 168 2020-09-09    4462978.0    73057.0  ...  74507.0         NaN         NaN
# 169        NaT          NaN        NaN  ...      NaN         NaN         0.0
#
# [170 rows x 8 columns]

# %%
df1 = df[["Date","Deaths"]]
df1.head()
# Out:
#         Date  Deaths
# 0 2020-03-25    10.0
# 1 2020-03-26    10.0
# 2 2020-03-27    16.0
# 3 2020-03-28    19.0
# 4 2020-03-29    25.0

# %%
# plot the time series
df1['Deaths'].plot()
plt.show()

# %%
# prepare expected column names
df1.columns = ['ds', 'y']
df1['ds']= pd.to_datetime(df1['ds'])

# %%
from fbprophet import Prophet
# define the model
model = Prophet()
# fit the model
model.fit(df1)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
prediction_size = 90
# define the period for which we want a prediction
future = model.make_future_dataframe(prediction_size)
future.tail()
# Out:
#             ds
# 255 2020-12-04
# 256 2020-12-05
# 257 2020-12-06
# 258 2020-12-07
# 259 2020-12-08

# %%
df = df.reset_index(drop=True).dropna()
df1 = df1.reset_index(drop=True).dropna()
future = future.reset_index(drop=True).dropna()

# %%
forecast = model.predict(future)
forecast.tail()
# Out:
#             ds          trend  ...  multiplicative_terms_upper           yhat
# 254 2020-12-04  156544.966420  ...                         0.0  156558.970928
# 255 2020-12-05  157503.632035  ...                         0.0  157502.315639
# 256 2020-12-06  158462.297650  ...                         0.0  158444.111353
# 257 2020-12-07  159420.963265  ...                         0.0  159364.963978
# 258 2020-12-08  160379.628881  ...                         0.0  160392.086380
#
# [5 rows x 16 columns]

# %%
model.plot_components(forecast)

# %%
model.plot(forecast,xlabel = 'Date', ylabel = 'Deaths')

# %%
import plotly.graph_objs as go
import plotly.offline as py
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
trace = go.Scatter(
    name = 'Actual Death',
    mode = 'markers',
    x = list(df1['ds']),
    y = list(df1['y']),
    marker=dict(
        color='#FFBAD2',
        line=dict(width=1)
    )
)
trace1 = go.Scatter(
    name = 'trend',
    mode = 'lines',
    x = list(forecast['ds']),
    y = list(forecast['yhat']),
    marker=dict(
        color='red',
        line=dict(width=3)
    )
)
upper_band = go.Scatter(
    name = 'upper band',
    mode = 'lines',
    x = list(forecast['ds']),
    y = list(forecast['yhat_upper']),
    line= dict(color='#57b88f'),
    fill = 'tonexty'
)
lower_band = go.Scatter(
    name= 'lower band',
    mode = 'lines',
    x = list(forecast['ds']),
    y = list(forecast['yhat_lower']),
    line= dict(color='#1705ff')
)

tracex = go.Scatter(
    name = 'Actual Death',
   mode = 'markers',
   x = list(df1['ds']),
   y = list(df1['y']),
   marker=dict(
      color='black',
      line=dict(width=2)
   )
)
data = [tracex, trace1, lower_band, upper_band, trace]

layout = dict(title='Death prediction due to covid-19 Using FbProphet',
             xaxis=dict(title = 'Dates', ticklen=2, zeroline=True))

figure=dict(data=data,layout=layout)

# %%
plt.savefig('forecastcovid_death.png')

# %%
py.offline.iplot(figure)
plt.show()
# Out:
# <div>
#
#
#             <div id="e721f50a-3034-48a8-82ac-5231516a38fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e721f50a-3034-48a8-82ac-5231516a38fa")) {
#                     Plotly.newPlot(
#                         'e721f50a-3034-48a8-82ac-5231516a38fa',
#                         [{"marker": {"color": "black", "line": {"width": 2}}, "mode": "markers", "name": "Actual Death", "type": "scatter", "x": ["2020-03-25T00:00:00", "2020-03-26T00:00:00", "2020-03-27T00:00:00", "2020-03-28T00:00:00", "2020-03-29T00:00:00", "2020-03-30T00:00:00", "2020-03-31T00:00:00", "2020-04-01T00:00:00", "2020-04-02T00:00:00", "2020-04-03T00:00:00", "2020-04-04T00:00:00", "2020-04-05T00:00:00", "2020-04-06T00:00:00", "2020-04-07T00:00:00", "2020-04-08T00:00:00", "2020-04-09T00:00:00", "2020-04-10T00:00:00", "2020-04-11T00:00:00", "2020-04-12T00:00:00", "2020-04-13T00:00:00", "2020-04-14T00:00:00", "2020-04-15T00:00:00", "2020-04-16T00:00:00", "2020-04-17T00:00:00", "2020-04-18T00:00:00", "2020-04-19T00:00:00", "2020-04-20T00:00:00", "2020-04-21T00:00:00", "2020-04-22T00:00:00", "2020-04-23T00:00:00", "2020-04-24T00:00:00", "2020-04-25T00:00:00", "2020-04-26T00:00:00", "2020-04-27T00:00:00", "2020-04-28T00:00:00", "2020-04-29T00:00:00", "2020-04-30T00:00:00", "2020-05-01T00:00:00", "2020-05-02T00:00:00", "2020-05-03T00:00:00", "2020-05-04T00:00:00", "2020-05-05T00:00:00", "2020-05-06T00:00:00", "2020-05-07T00:00:00", "2020-05-08T00:00:00", "2020-05-09T00:00:00", "2020-05-10T00:00:00", "2020-05-11T00:00:00", "2020-05-12T00:00:00", "2020-05-13T00:00:00", "2020-05-14T00:00:00", "2020-05-15T00:00:00", "2020-05-16T00:00:00", "2020-05-17T00:00:00", "2020-05-18T00:00:00", "2020-05-19T00:00:00", "2020-05-20T00:00:00", "2020-05-21T00:00:00", "2020-05-22T00:00:00", "2020-05-23T00:00:00", "2020-05-24T00:00:00", "2020-